# %%
# Quiz as a class created 
# To admin needs username , password for entry, Data for every student is also recorded
# As admin , one can create , delete , add question paper and admin can check the scorecard for all participants
# As student, one can appear for quiz and can see their result along with correct answers , at the end of quiz

# %%
class quiz_project:
    topics=[]
    questions={}
    options={}
    answers={}
    difficulty_level={}
    responses={}
    student_data=[]
    total=0
    scores={}
    
    def __init__ (self):
        self.menu()
    
    def menu(self):
        print("please enter your role: \n1:Admin\n2:Student\n3.Exit\n>>")
        n=int(input())
        if n==1:
            self.Admin()
        elif n==2:
            if quiz_project.questions!={}:
                self.Student()
            else:
                print("\n!! Quiz has not been graded yet!!!\n")
                self.menu()
        elif n==3:
            return None
        else:
            print("Please choose a valid option\n")
            self.menu()
            
    def Admin(self):
        username=input("Please enter the username: ")
        password=input("please enter the password: ")
        if username== 'admin@super' and password=='admin@123':
            self.Adminmenu()
        else:
            print("Enter valid username\n")
            self.Admin()
    def Adminmenu(self):
        print("\n1.Add questions\n2.Display questions\n3.Delete quiz\n4.Scoreboard\n5.Exit\n>>")
        n=int(input())
        if n==1:
            self.Addques()
        elif n==2:
            self.display()
        elif n==3:
            self.clear_quiz()
        elif n==4:
            self.scoreboard()
        elif n==5:
            self.menu()
        else:
            print("Enter valid choice\n")
            self.Adminmenu()
            
    def clear_quiz(self):
        quiz_project.topics=[]
        quiz_project.questions={}
        quiz_project.options={}
        quiz_project.answers={}
        quiz_project.difficulty_level={}
        quiz_project.responses=[]
        quiz_project.student_data=[]
        quiz_project.total=0
        print("The quiz has been deleted")
        self.Adminmenu()
        
    def scoreboard(self):
        print("Name".ljust(20),"Email".ljust(20),"Percentage")
        for i in quiz_project.student_data:
            print((i[0]).ljust(20),(i[1]).ljust(20),quiz_project.scores[i[0]])
        self.Adminmenu()
        
    def Addques(self):
        a=input("Please enter the questions:\n")
        x=input("The question topic: ")
        c=int(input("Choose the difficulty level\n1.Easy 2.Medium 3.Hard\nChoose(1,2,3) >>"))
        while(c>3):
            c=int(input("Choose the difficulty level\n1.Easy 2.Medium 3.Hard\nChoose(1,2,3) >>"))
        b=x.lower()
        if b not in quiz_project.topics:
            quiz_project.topics.append(b)
            quiz_project.questions[b]=[]
            quiz_project.options[b]=[]
            quiz_project.answers[b]=[]
            quiz_project.difficulty_level[b]=[]
            
        quiz_project.questions[b].append(a)
        
        if c==1:
            quiz_project.difficulty_level[b].append(5)
            quiz_project.total+=5
        elif c==2:
            quiz_project.difficulty_level[b].append(10)
            quiz_project.total+=10
        elif c==3:
            quiz_project.difficulty_level[b].append(20)
            quiz_project.total+=20
            
        arr=[]
        print("The options are: ")
        for i in range(1,5):
            print(i,":",end='')
            arr.append(input())
        quiz_project.options[b].append(arr)
        
        print("The correct option is:\n>>")
        quiz_project.answers[b].append(int(input()))
        
        if input("Would you like to add more questions ? Yes(Y)/No(N)") in "Yy":
            self.Addques()
            
        else:
            self.Adminmenu()
            
    def total_marks(self,name):
        if name in quiz_project.responses:
            sum1=0
            for i in quiz_project.topics:
                sum1+=sum(quiz_project.responses[name][i])
            return sum1
        else:
            print("!! Name does not exist in the list !!")
    def Student(self):
        self.stdname=input("Enter your name:")
        self.stdmail=input("Enter your email:")
        quiz_project.student_data.append([self.stdname,self.stdmail])
        quiz_project.responses[self.stdname]={}
        print("--------------The Test is starting----------\nEasy question is for 5 marks\nMedium question is for 10 Marks\nHard question is for 20 Marks\n")
        if input("Press any key to start>>")!='':
            for i in range(len(quiz_project.questions)):
                a=quiz_project.topics[i]
                quiz_project.responses[self.stdname][a]=[]
                print("___",a.upper(),"___")
                for j in range(len(quiz_project.questions[a])):
                    print("\n",quiz_project.questions[a][j])
                    for k in range(0,4):
                        print(k+1,":",quiz_project.options[a][j][k])
                    check=int(input("Enter the option:"))
                    if check==quiz_project.answers[a][j]:
                        quiz_project.responses[self.stdname][a].append(quiz_project.difficulty_level[a][j])
                    else:
                        quiz_project.responses[self.stdname][a].append(0)
        print("\n\nCORRECT ANSWERS ARE\n")
        for i in range(len(quiz_project.questions)):
            a=quiz_project.topics[i]
            print("\n___",a.upper(),"___\n")
            for j in range(len(quiz_project.questions[a])):
                print("\n",quiz_project.questions[a][j])
                for k in range(0,4):
                    print(k+1,quiz_project.options[a][j][k])
                print("CORRECT ANSWER>>",quiz_project.answers[a][j],'\n')
                
        res=self.total_marks(self.stdname)
        print(self.stdname,"your score is",res,'/',quiz_project.total,"\n\n")
        
        quiz_project.scores[self.stdname]=res/quiz_project.total*100
        
        self.menu()
        
    def display(self):
        for i in range(len(quiz_project.questions)):
            a=quiz_project.topics[i]
            print("\n___",a.upper(),"___\n")
            for j in range(len(quiz_project.questions[a])):
                print("\n",quiz_project.questions[a][j])
                for k in range(0,4):
                    print(k+1,quiz_project.options[a][j][k])
        self.Adminmenu()
            
start=quiz_project()
# Out:
# please enter your role:
# 1:Admin
# 2:Student
# 3.Exit
# >>
# 1
# Please enter the username: admin@supe
# please enter the password: admin@123
# Enter valid username
#
# Please enter the username: admin@super
# please enter the password: admin@123
#
# 1.Add questions
# 2.Display questions
# 3.Delete quiz
# 4.Scoreboard
# 5.Exit
# >>
# 1
# Please enter the questions:
# Who is PM of India?
# The question topic: Politics
# Choose the difficulty level
# 1.Easy 2.Medium 3.Hard
# Choose(1,2,3) >>2
# The options are:
# 1 :Biden
# 2 :Modi
# 3 :Rahul Gandhi
# 4 :Ram Nath Kovind
# The correct option is:
# >>
# 2
# Would you like to add more questions ? Yes(Y)/No(N)Y
# Please enter the questions:
# Most abundant gas in atmosphere ?
# The question topic: Chemistry
# Choose the difficulty level
# 1.Easy 2.Medium 3.Hard
# Choose(1,2,3) >>3
# The options are:
# 1 :oxygen
# 2 :helium
# 3 :nitrogen
# 4 :phosphene
# The correct option is:
# >>
# 3
# Would you like to add more questions ? Yes(Y)/No(N)Y
# Please enter the questions:
# Capital Of Pakistan ?
# The question topic: Geology
# Choose the difficulty level
# 1.Easy 2.Medium 3.Hard
# Choose(1,2,3) >>1
# The options are:
# 1 :Karachi
# 2 :kabul
# 3 :Lahore
# 4 :Islamabad
# The correct option is:
# >>
# 4
# Would you like to add more questions ? Yes(Y)/No(N)N
#
# 1.Add questions
# 2.Display questions
# 3.Delete quiz
# 4.Scoreboard
# 5.Exit
# >>
# 5
# please enter your role:
# 1:Admin
# 2:Student
# 3.Exit
# >>
# 2
# Enter your name:Ram
# Enter your email:ram@gmail.com
# --------------The Test is starting----------
# Easy question is for 5 marks
# Medium question is for 10 Marks
# Hard question is for 20 Marks
#
# Press any key to start>>t
# ___ POLITICS ___
#
#  Who is PM of India?
# 1 : Biden
# 2 : Modi
# 3 : Rahul Gandhi
# 4 : Ram Nath Kovind
# Enter the option:2
# ___ CHEMISTRY ___
#
#  Most abundant gas in atmosphere ?
# 1 : oxygen
# 2 : helium
# 3 : nitrogen
# 4 : phosphene
# Enter the option:3
# ___ GEOLOGY ___
#
#  Capital Of Pakistan ?
# 1 : Karachi
# 2 : kabul
# 3 : Lahore
# 4 : Islamabad
# Enter the option:4
#
#
# CORRECT ANSWERS ARE
#
#
# ___ POLITICS ___
#
#
#  Who is PM of India?
# 1 Biden
# 2 Modi
# 3 Rahul Gandhi
# 4 Ram Nath Kovind
# CORRECT ANSWER>> 2
#
#
# ___ CHEMISTRY ___
#
#
#  Most abundant gas in atmosphere ?
# 1 oxygen
# 2 helium
# 3 nitrogen
# 4 phosphene
# CORRECT ANSWER>> 3
#
#
# ___ GEOLOGY ___
#
#
#  Capital Of Pakistan ?
# 1 Karachi
# 2 kabul
# 3 Lahore
# 4 Islamabad
# CORRECT ANSWER>> 4
#
# Ram your score is 35 / 35
#
#
# please enter your role:
# 1:Admin
# 2:Student
# 3.Exit
# >>
# 2
# Enter your name:John
# Enter your email:j@gmail.com
# --------------The Test is starting----------
# Easy question is for 5 marks
# Medium question is for 10 Marks
# Hard question is for 20 Marks
#
# Press any key to start>>3
# ___ POLITICS ___
#
#  Who is PM of India?
# 1 : Biden
# 2 : Modi
# 3 : Rahul Gandhi
# 4 : Ram Nath Kovind
# Enter the option:1
# ___ CHEMISTRY ___
#
#  Most abundant gas in atmosphere ?
# 1 : oxygen
# 2 : helium
# 3 : nitrogen
# 4 : phosphene
# Enter the option:3
# ___ GEOLOGY ___
#
#  Capital Of Pakistan ?
# 1 : Karachi
# 2 : kabul
# 3 : Lahore
# 4 : Islamabad
# Enter the option:3
#
#
# CORRECT ANSWERS ARE
#
#
# ___ POLITICS ___
#
#
#  Who is PM of India?
# 1 Biden
# 2 Modi
# 3 Rahul Gandhi
# 4 Ram Nath Kovind
# CORRECT ANSWER>> 2
#
#
# ___ CHEMISTRY ___
#
#
#  Most abundant gas in atmosphere ?
# 1 oxygen
# 2 helium
# 3 nitrogen
# 4 phosphene
# CORRECT ANSWER>> 3
#
#
# ___ GEOLOGY ___
#
#
#  Capital Of Pakistan ?
# 1 Karachi
# 2 kabul
# 3 Lahore
# 4 Islamabad
# CORRECT ANSWER>> 4
#
# John your score is 20 / 35
#
#
# please enter your role:
# 1:Admin
# 2:Student
# 3.Exit
# >>
# 1
# Please enter the username: admin@super
# please enter the password: admin@123
#
# 1.Add questions
# 2.Display questions
# 3.Delete quiz
# 4.Scoreboard
# 5.Exit
# >>
# 4
# Name                 Email                Percentage
# Ram                  ram@gmail.com        100.0
# John                 j@gmail.com          57.14285714285714
#
# 1.Add questions
# 2.Display questions
# 3.Delete quiz
# 4.Scoreboard
# 5.Exit
# >>
# 5
# please enter your role:
# 1:Admin
# 2:Student
# 3.Exit
# >>
# 3
